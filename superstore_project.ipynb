# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/minht/.vscode/extensions/FULL STACK/python/all_project_for_work/data/superstore.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
data.shape
# Out:
# (51290, 27)

# %%
data.dtypes
# Out:
# Category           object
# City               object
# Country            object
# Customer.ID        object
# Customer.Name      object
# Discount          float64
# Market             object
# 记录数                 int64
# Order.Date         object
# Order.ID           object
# Order.Priority     object
# Product.ID         object
# Product.Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row.ID              int64
# Sales               int64
# Segment            object
# Ship.Date          object
# Ship.Mode          object
# Shipping.Cost     float64
# State              object
# Sub.Category       object
# Year                int64
# Market2            object
# weeknum             int64
# dtype: object

# %%
data.sample(5)
# Out:
#               Category         City        Country Customer.ID  \
# 32929  Office Supplies  Spijkenisse    Netherlands   BG-116952
# 28825        Furniture    San Diego  United States   RB-194354
# 13227  Office Supplies       Ashdod         Israel     AS-1352
# 28351       Technology      Seattle  United States   CM-118154
# 44989  Office Supplies   Gold Coast      Australia   JE-156101
#
#            Customer.Name  Discount Market  记录数               Order.Date  \
# 32929  Brooke Gillingham       0.5     EU    1  2013-12-13 00:00:00.000
# 28825    Richard Bierner       0.0     US    1  2012-03-29 00:00:00.000
# 13227       Adrian Shami       0.0   EMEA    1  2013-10-11 00:00:00.000
# 28351    Candace McMahon       0.0     US    1  2014-08-22 00:00:00.000
# 44989            Jim Epp       0.1   APAC    1  2014-06-11 00:00:00.000
#
#               Order.ID  ... Sales      Segment                Ship.Date  \
# 32929  IT-2013-2598339  ...    74    Corporate  2013-12-13 00:00:00.000
# ...

# %%
data.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
data.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df = data.copy()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df.drop(columns=["记录数"], inplace=True)

# %%
df["Order.Date"] = pd.to_datetime(df["Order.Date"])
df["Ship.Date"] = pd.to_datetime(df["Ship.Date"])
df[["Order.Date", "Ship.Date"]].dtypes
# Out:
# Order.Date    datetime64[ns]
# Ship.Date     datetime64[ns]
# dtype: object

# %%
(df["Sales"] < 0).sum()
# Out:
# np.int64(0)

# %%
(df["Sales"] == 0).sum()
# Out:
# np.int64(1)

# %%
df[df["Sales"] <= 0]
# Out:
#               Category     City        Country Customer.ID     Customer.Name  \
# 46158  Office Supplies  Houston  United States   ZC-219104  Zuschuss Carroll
#
#        Discount Market Order.Date        Order.ID Order.Priority  ... Sales  \
# 46158       0.8     US 2014-06-20  US-2014-102288         Medium  ...     0
#
#         Segment  Ship.Date       Ship.Mode Shipping.Cost  State  Sub.Category  \
# 46158  Consumer 2014-06-24  Standard Class          0.01  Texas    Appliances
#
#        Year        Market2 weeknum
# 46158  2014  North America      25
#
# [1 rows x 26 columns]

# %%
(df["Profit"] < 0).sum()
# Out:
# np.int64(12544)

# %%
(df["Discount"] < 0).sum()
# Out:
# np.int64(0)

# %%
(df["Discount"] > 1).sum()
# Out:
# np.int64(0)

# %%
(df["Quantity"] <= 0).sum()
# Out:
# np.int64(0)

# %%
(df["Shipping.Cost"] < 0).sum()
# Out:
# np.int64(0)

# %%
df["Row.ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Customer.ID"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Customer.ID"].nunique()
# Out:
# 4873

# %%
df["Product.ID"].nunique()
# Out:
# 10292

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: count, dtype: int64

# %%
df["Market"].value_counts()
# Out:
# Market
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: count, dtype: int64

# %%
df["Ship.Mode"].value_counts()
# Out:
# Ship.Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %%
numeric_cols = [
    "Sales",
    "Profit",
    "Quantity",
    "Discount",
    "Shipping.Cost"
]
plt.figure(figsize=(15, 8))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}")
    print(f"Number of outliers: {len(outliers)}")
# Out:
# Sales
# Number of outliers: 5655
# Profit
# Number of outliers: 9755
# Quantity
# Number of outliers: 877
# Discount
# Number of outliers: 4172
# Shipping.Cost
# Number of outliers: 5909

# %%
plt.figure(figsize=(8,6))

corr = df[numeric_cols].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix")
plt.show()

# %%
df.to_csv("superstore_cleaned.csv", index=False)
